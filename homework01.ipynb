# %%
from PIL import Image
from pylab import *
import numpy as np
import pandas as pd
import matplotlib

# %%
im=array(Image.open(r"D:\1.jpg"))
imshow(im)
#figure()

# %%
#im = matplotlib.image.imread(r'D:\1.jpg')
#imshow(im)
#figure()

# %%
#灰度化
infile= r'D:\1.jpg'
outfile= r'D:\1_2.jpg' #灰度化后的图像路径

out = im.convert('L') #灰度化
out = im.resize((432,288),Image.ANTIALIAS) #重新定义图片尺寸大小
out.save(outfile) #存储图片
imshow(im)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-7af66dec8c37> in <module>()
#       3 outfile= r'D:\1_2.jpg' #灰度化后的图像路径
#       4
# ----> 5 out = im.convert('L') #灰度化
#       6 out = im.resize((432,288),Image.ANTIALIAS) #重新定义图片尺寸大小
#       7 out.save(outfile) #存储图片
#
# AttributeError: 'numpy.ndarray' object has no attribute 'convert'

# %%
#降采样
def dsample(I,N):
    Idown = dsample(I,N)
    [row,col]=size(I)
    drow=round(row/N)
    dcol=round(col/N)
    Idown=zeros(drow,dcol)
    p=1
    q=1
    for i in range(1,row+1,N):
        for j in range(1,col+1,N):
            Idown(p,q)=I(i,j)
            q=q+1
        q=1
        p=p+1
# Out:
#   File "<ipython-input-12-1e1576bcbc0d>", line 12
#     Idown(p,q)=I(i,j)
#     ^
# SyntaxError: can't assign to function call

# %%
#降采样
[row,col]=size(im)
print(row)
# Out:
# 530
